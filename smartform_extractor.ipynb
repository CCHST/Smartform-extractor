# %%
# !pip install docx
# !pip install smartsheet-python-sdk
# !pip install --upgrade --force-reinstall python-docx

import re
import time
import smartsheet
import unicodedata
import pandas as pd
from docx import Document
from smartsheet.models import Column, Sheet
from typing import List, Dict, Any, Optional
# Out:
# Requirement already satisfied: smartsheet-python-sdk in /usr/local/lib/python3.11/dist-packages (3.0.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from smartsheet-python-sdk) (2.32.3)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from smartsheet-python-sdk) (1.0.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from smartsheet-python-sdk) (1.17.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from smartsheet-python-sdk) (2025.4.26)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from smartsheet-python-sdk) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->smartsheet-python-sdk) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->smartsheet-python-sdk) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->smartsheet-python-sdk) (2.4.0)
# Collecting python-docx
#   Using cached python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting lxml>=3.1.0 (from python-docx)
#   Using cached lxml-5.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Collecting typing-extensions>=4.9.0 (from python-docx)
#   Using cached typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Using cached python_docx-1.1.2-py3-none-any.whl (244 kB)
# Using cached lxml-5.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.9 MB)
# Using cached typing_extensions-4.14.0-py3-none-any.whl (43 kB)
# Installing collected packages: typing-extensions, lxml, python-docx
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.14.0
#     Uninstalling typing_extensions-4.14.0:
#       Successfully uninstalled typing_extensions-4.14.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 5.4.0
#     Uninstalling lxml-5.4.0:
#       Successfully uninstalled lxml-5.4.0
#   Attempting uninstall: python-docx
#     Found existing installation: python-docx 1.1.2
#     Uninstalling python-docx-1.1.2:
#       Successfully uninstalled python-docx-1.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# Successfully installed lxml-5.4.0 python-docx-1.1.2 typing-extensions-4.14.0

# %%
# Find your sheetid
# 🔐 Step 1: Authenticate using your Smartsheet API token
SMARTSHEET_API_TOKEN = "Your API Token"
ss = smartsheet.Smartsheet(SMARTSHEET_API_TOKEN)

# 📄 Step 2: List all sheets you have access to
response = ss.Sheets.list_sheets()

# 📋 Step 3: Print sheet names and their IDs
for sheet in response.data:
    print(f"Sheet Name: {sheet.name} | Sheet ID: {sheet.id}")

# %%
SHEET_ID = 12345678 # Insert your sheet id

# %% [markdown]
# ### AI generated-paste your own code here

# %%
def parse_supplier_change_order():
    """
    Clean parser for the Supplier Change Order form fields
    Returns a list of form fields with their types and options
    """

    form_fields = []

    # Section 1: Supplier Information
    form_fields.extend([
        {
            "field_name": "Type of Change",
            "type": "dropdown",
            "options": ["New Supplier", "Re-classification", "Remove Supplier", "Administrative Change"]
        },
        {
            "field_name": "New Supplier Sub-type",
            "type": "dropdown",
            "options": ["Secondary/Alternate", "Experimental/R&D Evaluation", "NPI"]
        },
        {
            "field_name": "Reason for Change",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Supplier Company Name",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Supplier Address",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Supplier Phone Number",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Supplier Website",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Primary Contact 1 Name",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Primary Contact 1 Title",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Primary Contact 1 Email",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Primary Contact 2 Name",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Primary Contact 2 Title",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Primary Contact 2 Email",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Supplier Type",
            "type": "dropdown",
            "options": ["Manufacturer of a Good", "Vendor", "Packaging Supplier"]
        },
        {
            "field_name": "Vendor Sub-type",
            "type": "dropdown",
            "options": ["Service Provider", "Distributor"]
        },
        {
            "field_name": "Contract Required for Service Provider",
            "type": "dropdown",
            "options": ["Yes", "No"]
        },
        {
            "field_name": "NDA Required",
            "type": "dropdown",
            "options": ["Yes", "No"]
        },
        {
            "field_name": "NDA Effective Date",
            "type": "date",
            "options": None
        },
        {
            "field_name": "NDA Term or Duration",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Part or Service Description",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Supplier Catalog Numbers",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Part/Service Type",
            "type": "dropdown",
            "options": ["Off-the-Shelf", "Custom", "One-time"]
        },
        {
            "field_name": "Supplier Source Type",
            "type": "dropdown",
            "options": ["Sole Source", "One of 2 Sources", "One of ≥3 Sources"]
        },
        {
            "field_name": "Associated System/Instrument/Process",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Estimated Annual Spend",
            "type": "number",
            "options": None
        },
        {
            "field_name": "Origin of Part or Service",
            "type": "dropdown",
            "options": ["USA", "Canada", "Mexico", "EMEA", "APAC"]
        },
        {
            "field_name": "EMEA/APAC Country Specification",
            "type": "text",
            "options": None
        }
    ])

    # Product Usage Questions (Yes/No dropdowns)
    yes_no_questions = [
        "Used in Manufacture or Testing",
        "Used for RUO/GMP/IVD Product",
        "Product Exported to EU",
        "Supplier Provides GMP/IVD Product",
        "Supplier Provides IVD Device (ProteinSimple Legal Manufacturer)",
        "Product for IVD Sold in EU Under IVDR",
        "Impacts Design Outputs for RUO/GMP/IVD",
        "Influences Test Result",
        "Raw Material Requires In-house Testing",
        "Requires Process Validation"
    ]

    for question in yes_no_questions:
        form_fields.append({
            "field_name": question,
            "type": "dropdown",
            "options": ["Yes", "No"]
        })

    form_fields.append({
        "field_name": "Internal Lead Time",
        "type": "dropdown",
        "options": ["≤ 1 week", "1-2 weeks", "2-4 weeks", "4-6 weeks", "6-8 weeks", ">9 weeks"]
    })

    # Section 2: Financial Information
    form_fields.extend([
        {
            "field_name": "Supplier Tax ID/SS#",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Payment Terms",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Payment Method",
            "type": "dropdown",
            "options": ["Check", "Wire", "ACH", "Credit Card"]
        },
        {
            "field_name": "Is 1099 Vendor",
            "type": "dropdown",
            "options": ["Yes", "No"]
        },
        {
            "field_name": "ACH Payee Name",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Bank Routing Number",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Bank Name",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Bank Account Number",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Bank Address",
            "type": "text",
            "options": None
        }
    ])

    # Section 3: Risk Assessment
    risk_domains = [
        "Financial Health",
        "Country/Geopolitical",
        "ESG Compliance",
        "Regulatory Exposure",
        "Operational Risk",
        "Cybersecurity Risk",
        "Supply Market Risk",
        "Benchmark Performance"
    ]

    for domain in risk_domains:
        form_fields.extend([
            {
                "field_name": f"{domain} - Likelihood",
                "type": "dropdown",
                "options": ["1", "2", "3", "4", "5"]
            },
            {
                "field_name": f"{domain} - Impact",
                "type": "dropdown",
                "options": ["1", "2", "3", "4", "5"]
            }
        ])

    form_fields.extend([
        {
            "field_name": "Risk Mitigation Actions",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Risk Mitigation Task Owners",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Risk Mitigation Completion Date",
            "type": "date",
            "options": None
        }
    ])

    # Section 4: Classification
    form_fields.append({
        "field_name": "Supplier Classification",
        "type": "dropdown",
        "options": ["Critical", "Major", "Minor", "Contractor/Consultant"]
    })

    # Required Documentation Tracking
    doc_items = [
        "Supplier Code of Conduct",
        "Supplier Change Notification",
        "Supplier Evaluation Questionnaire",
        "Supplier Quality Agreement",
        "Quality System Certifications",
        "Resume/CV",
        "Supplier Quality Audit"
    ]

    for doc in doc_items:
        form_fields.extend([
            {
                "field_name": f"{doc} - Submitted Date",
                "type": "date",
                "options": None
            },
            {
                "field_name": f"{doc} - Received Date",
                "type": "date",
                "options": None
            }
        ])

    form_fields.extend([
        {
            "field_name": "Audit Type",
            "type": "dropdown",
            "options": ["N/A", "Remote", "On-Site"]
        },
        {
            "field_name": "Audit Justification",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Audit Scheduled Date",
            "type": "date",
            "options": None
        }
    ])

    # Section 5: Disposition
    form_fields.extend([
        {
            "field_name": "Final Type of Change",
            "type": "dropdown",
            "options": ["New Supplier", "Re-classification", "Remove Supplier", "Administrative Change"]
        },
        {
            "field_name": "Approval Status",
            "type": "dropdown",
            "options": ["Approved", "Conditional Approval", "Not Approved", "Removed"]
        },
        {
            "field_name": "Conditional Approval Timeline",
            "type": "text",
            "options": None
        },
        {
            "field_name": "Conditional Approval Conditions",
            "type": "text",
            "options": None
        }
    ])

    # Section 6: System Updates
    form_fields.extend([
        {
            "field_name": "Supplier ID (MAS ERP)",
            "type": "text",
            "options": None
        },
        {
            "field_name": "MAS ERP Update Date",
            "type": "date",
            "options": None
        },
        {
            "field_name": "ASL Update Date",
            "type": "date",
            "options": None
        },
        {
            "field_name": "Arena e-QMS Update Date",
            "type": "date",
            "options": None
        }
    ])

    # Signature fields
    signature_fields = [
        "Requestor Name", "Requestor Department", "Request Date",
        "Procurement Name", "Procurement Date",
        "Supplier Quality Name", "Supplier Quality Date",
        "Final Approver Name", "Final Approval Date"
    ]

    for sig_field in signature_fields:
        form_fields.append({
            "field_name": sig_field,
            "type": "text" if "Name" in sig_field or "Department" in sig_field else "date",
            "options": None
        })

    return form_fields

# %% [markdown]
# ### Execution

# %%
# Execute the parsing and convert to columns/dropdowns format
fields = parse_supplier_change_order()

# Convert to the format your existing code expects
columns = []
dropdowns = []

for field in fields:
    columns.append(field["field_name"])
    dropdowns.append(field["options"])  # Will be None for text fields, list for dropdowns

print(f"Extracted {len(columns)} form fields from Supplier Change Order:")
print(f"Ready for your existing Smartsheet processing code!")
print("\n" + "="*60)

# Show the data in the format your code expects
current_section = ""
for i, (col, opts) in enumerate(zip(columns, dropdowns)):
    # Simple section detection based on field names
    if col.startswith("Type of Change") and i == 0:
        current_section = "SECTION 1: SUPPLIER INFORMATION"
        print(f"\n{current_section}")
        print("-" * len(current_section))
    elif col.startswith("Supplier Tax ID"):
        current_section = "SECTION 2: FINANCIAL INFORMATION"
        print(f"\n{current_section}")
        print("-" * len(current_section))
    elif col.endswith("Likelihood"):
        current_section = "SECTION 3: RISK ASSESSMENT"
        print(f"\n{current_section}")
        print("-" * len(current_section))
    elif col == "Supplier Classification":
        current_section = "SECTION 4: CLASSIFICATION & DOCUMENTATION"
        print(f"\n{current_section}")
        print("-" * len(current_section))
    elif col == "Final Type of Change":
        current_section = "SECTION 5: FINAL DISPOSITION"
        print(f"\n{current_section}")
        print("-" * len(current_section))
    elif col.startswith("Supplier ID"):
        current_section = "SECTION 6: SYSTEM UPDATES & SIGNATURES"
        print(f"\n{current_section}")
        print("-" * len(current_section))

    # Display in the format matching your existing code
    print(f" - {col} | Dropdown: {opts}")
    if opts:
        print(f"   🔽 Dropdown Options: {', '.join(opts)}")
    else:
        print("   📝 Input Type: Free text")

print(f"\n" + "="*60)
print(f"SUMMARY: Created columns and dropdowns lists with {len(columns)} items")
print(f"Dropdown fields: {len([d for d in dropdowns if d])}")
print(f"Text/Date fields: {len([d for d in dropdowns if not d])}")
print("\n✅ You can now use the 'columns' and 'dropdowns' variables with your existing Smartsheet code!")
# Out:
# Extracted 101 form fields from Supplier Change Order:
# Ready for your existing Smartsheet processing code!
#
# ============================================================
#
# SECTION 1: SUPPLIER INFORMATION
# -------------------------------
#  - Type of Change | Dropdown: ['New Supplier', 'Re-classification', 'Remove Supplier', 'Administrative Change']
#    🔽 Dropdown Options: New Supplier, Re-classification, Remove Supplier, Administrative Change
#  - New Supplier Sub-type | Dropdown: ['Secondary/Alternate', 'Experimental/R&D Evaluation', 'NPI']
#    🔽 Dropdown Options: Secondary/Alternate, Experimental/R&D Evaluation, NPI
#  - Reason for Change | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Company Name | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Address | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Phone Number | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Website | Dropdown: None
#    📝 Input Type: Free text
#  - Primary Contact 1 Name | Dropdown: None
#    📝 Input Type: Free text
#  - Primary Contact 1 Title | Dropdown: None
#    📝 Input Type: Free text
#  - Primary Contact 1 Email | Dropdown: None
#    📝 Input Type: Free text
#  - Primary Contact 2 Name | Dropdown: None
#    📝 Input Type: Free text
#  - Primary Contact 2 Title | Dropdown: None
#    📝 Input Type: Free text
#  - Primary Contact 2 Email | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Type | Dropdown: ['Manufacturer of a Good', 'Vendor', 'Packaging Supplier']
#    🔽 Dropdown Options: Manufacturer of a Good, Vendor, Packaging Supplier
#  - Vendor Sub-type | Dropdown: ['Service Provider', 'Distributor']
#    🔽 Dropdown Options: Service Provider, Distributor
#  - Contract Required for Service Provider | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - NDA Required | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - NDA Effective Date | Dropdown: None
#    📝 Input Type: Free text
#  - NDA Term or Duration | Dropdown: None
#    📝 Input Type: Free text
#  - Part or Service Description | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Catalog Numbers | Dropdown: None
#    📝 Input Type: Free text
#  - Part/Service Type | Dropdown: ['Off-the-Shelf', 'Custom', 'One-time']
#    🔽 Dropdown Options: Off-the-Shelf, Custom, One-time
#  - Supplier Source Type | Dropdown: ['Sole Source', 'One of 2 Sources', 'One of ≥3 Sources']
#    🔽 Dropdown Options: Sole Source, One of 2 Sources, One of ≥3 Sources
#  - Associated System/Instrument/Process | Dropdown: None
#    📝 Input Type: Free text
#  - Estimated Annual Spend | Dropdown: None
#    📝 Input Type: Free text
#  - Origin of Part or Service | Dropdown: ['USA', 'Canada', 'Mexico', 'EMEA', 'APAC']
#    🔽 Dropdown Options: USA, Canada, Mexico, EMEA, APAC
#  - EMEA/APAC Country Specification | Dropdown: None
#    📝 Input Type: Free text
#  - Used in Manufacture or Testing | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - Used for RUO/GMP/IVD Product | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - Product Exported to EU | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - Supplier Provides GMP/IVD Product | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - Supplier Provides IVD Device (ProteinSimple Legal Manufacturer) | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - Product for IVD Sold in EU Under IVDR | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - Impacts Design Outputs for RUO/GMP/IVD | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - Influences Test Result | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - Raw Material Requires In-house Testing | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - Requires Process Validation | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - Internal Lead Time | Dropdown: ['≤ 1 week', '1-2 weeks', '2-4 weeks', '4-6 weeks', '6-8 weeks', '>9 weeks']
#    🔽 Dropdown Options: ≤ 1 week, 1-2 weeks, 2-4 weeks, 4-6 weeks, 6-8 weeks, >9 weeks
#
# SECTION 2: FINANCIAL INFORMATION
# --------------------------------
#  - Supplier Tax ID/SS# | Dropdown: None
#    📝 Input Type: Free text
#  - Payment Terms | Dropdown: None
#    📝 Input Type: Free text
#  - Payment Method | Dropdown: ['Check', 'Wire', 'ACH', 'Credit Card']
#    🔽 Dropdown Options: Check, Wire, ACH, Credit Card
#  - Is 1099 Vendor | Dropdown: ['Yes', 'No']
#    🔽 Dropdown Options: Yes, No
#  - ACH Payee Name | Dropdown: None
#    📝 Input Type: Free text
#  - Bank Routing Number | Dropdown: None
#    📝 Input Type: Free text
#  - Bank Name | Dropdown: None
#    📝 Input Type: Free text
#  - Bank Account Number | Dropdown: None
#    📝 Input Type: Free text
#  - Bank Address | Dropdown: None
#    📝 Input Type: Free text
#
# SECTION 3: RISK ASSESSMENT
# --------------------------
#  - Financial Health - Likelihood | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#  - Financial Health - Impact | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#
# SECTION 3: RISK ASSESSMENT
# --------------------------
#  - Country/Geopolitical - Likelihood | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#  - Country/Geopolitical - Impact | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#
# SECTION 3: RISK ASSESSMENT
# --------------------------
#  - ESG Compliance - Likelihood | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#  - ESG Compliance - Impact | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#
# SECTION 3: RISK ASSESSMENT
# --------------------------
#  - Regulatory Exposure - Likelihood | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#  - Regulatory Exposure - Impact | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#
# SECTION 3: RISK ASSESSMENT
# --------------------------
#  - Operational Risk - Likelihood | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#  - Operational Risk - Impact | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#
# SECTION 3: RISK ASSESSMENT
# --------------------------
#  - Cybersecurity Risk - Likelihood | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#  - Cybersecurity Risk - Impact | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#
# SECTION 3: RISK ASSESSMENT
# --------------------------
#  - Supply Market Risk - Likelihood | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#  - Supply Market Risk - Impact | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#
# SECTION 3: RISK ASSESSMENT
# --------------------------
#  - Benchmark Performance - Likelihood | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#  - Benchmark Performance - Impact | Dropdown: ['1', '2', '3', '4', '5']
#    🔽 Dropdown Options: 1, 2, 3, 4, 5
#  - Risk Mitigation Actions | Dropdown: None
#    📝 Input Type: Free text
#  - Risk Mitigation Task Owners | Dropdown: None
#    📝 Input Type: Free text
#  - Risk Mitigation Completion Date | Dropdown: None
#    📝 Input Type: Free text
#
# SECTION 4: CLASSIFICATION & DOCUMENTATION
# -----------------------------------------
#  - Supplier Classification | Dropdown: ['Critical', 'Major', 'Minor', 'Contractor/Consultant']
#    🔽 Dropdown Options: Critical, Major, Minor, Contractor/Consultant
#  - Supplier Code of Conduct - Submitted Date | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Code of Conduct - Received Date | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Change Notification - Submitted Date | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Change Notification - Received Date | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Evaluation Questionnaire - Submitted Date | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Evaluation Questionnaire - Received Date | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Quality Agreement - Submitted Date | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Quality Agreement - Received Date | Dropdown: None
#    📝 Input Type: Free text
#  - Quality System Certifications - Submitted Date | Dropdown: None
#    📝 Input Type: Free text
#  - Quality System Certifications - Received Date | Dropdown: None
#    📝 Input Type: Free text
#  - Resume/CV - Submitted Date | Dropdown: None
#    📝 Input Type: Free text
#  - Resume/CV - Received Date | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Quality Audit - Submitted Date | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Quality Audit - Received Date | Dropdown: None
#    📝 Input Type: Free text
#  - Audit Type | Dropdown: ['N/A', 'Remote', 'On-Site']
#    🔽 Dropdown Options: N/A, Remote, On-Site
#  - Audit Justification | Dropdown: None
#    📝 Input Type: Free text
#  - Audit Scheduled Date | Dropdown: None
#    📝 Input Type: Free text
#
# SECTION 5: FINAL DISPOSITION
# ----------------------------
#  - Final Type of Change | Dropdown: ['New Supplier', 'Re-classification', 'Remove Supplier', 'Administrative Change']
#    🔽 Dropdown Options: New Supplier, Re-classification, Remove Supplier, Administrative Change
#  - Approval Status | Dropdown: ['Approved', 'Conditional Approval', 'Not Approved', 'Removed']
#    🔽 Dropdown Options: Approved, Conditional Approval, Not Approved, Removed
#  - Conditional Approval Timeline | Dropdown: None
#    📝 Input Type: Free text
#  - Conditional Approval Conditions | Dropdown: None
#    📝 Input Type: Free text
#
# SECTION 6: SYSTEM UPDATES & SIGNATURES
# --------------------------------------
#  - Supplier ID (MAS ERP) | Dropdown: None
#    📝 Input Type: Free text
#  - MAS ERP Update Date | Dropdown: None
#    📝 Input Type: Free text
#  - ASL Update Date | Dropdown: None
#    📝 Input Type: Free text
#  - Arena e-QMS Update Date | Dropdown: None
#    📝 Input Type: Free text
#  - Requestor Name | Dropdown: None
#    📝 Input Type: Free text
#  - Requestor Department | Dropdown: None
#    📝 Input Type: Free text
#  - Request Date | Dropdown: None
#    📝 Input Type: Free text
#  - Procurement Name | Dropdown: None
#    📝 Input Type: Free text
#  - Procurement Date | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Quality Name | Dropdown: None
#    📝 Input Type: Free text
#  - Supplier Quality Date | Dropdown: None
#    📝 Input Type: Free text
#  - Final Approver Name | Dropdown: None
#    📝 Input Type: Free text
#  - Final Approval Date | Dropdown: None
#    📝 Input Type: Free text
#
# ============================================================
# SUMMARY: Created columns and dropdowns lists with 101 items
# Dropdown fields: 42
# Text/Date fields: 59
#
# ✅ You can now use the 'columns' and 'dropdowns' variables with your existing Smartsheet code!

# %%
def normalize_title(text, max_length=50):
    """Normalize and truncate title for Smartsheet"""
    if not text:
        return None

    text = unicodedata.normalize("NFKC", str(text))
    text = text.replace("'", "'").replace("'", "'").replace(""", '"').replace(""", '"')
    text = text.strip()

    # Skip if only punctuation
    if not text or re.fullmatch(r"[:()\[\]]+", text):
        return None

    # Truncate to max length
    if len(text) > max_length:
        text = text[:max_length-3] + "..."

    return text

def normalize_option(text):
    """Normalize dropdown option"""
    if not text:
        return None

    text = unicodedata.normalize("NFKC", str(text))
    text = text.replace("'", "'").replace("'", "'").replace(""", '"').replace(""", '"')
    text = text.strip()

    # Skip if only punctuation or too short
    if not text or len(text) < 2 or re.fullmatch(r"[:()\[\]]+", text):
        return None

    return text

# Process columns for Smartsheet (your existing code goes here)
columns_to_add = []
used_titles = set()

for i, (col_title_raw, opts_raw) in enumerate(zip(columns, dropdowns)):
    title = normalize_title(col_title_raw, max_length=50)  # Enforce 50 char limit
    if not title:
        continue

    # Ensure unique titles
    original = title
    counter = 1
    while title in used_titles:
        suffix = f" ({counter})"
        max_base = 50 - len(suffix)
        if len(original) > max_base:
            title = original[:max_base] + suffix
        else:
            title = original + suffix
        counter += 1
    used_titles.add(title)

    # Process options
    options = None
    if opts_raw:
        options = [normalize_option(opt) for opt in opts_raw]
        options = [opt for opt in options if opt]  # Remove None values

        # Limit number of options (Smartsheet has limits)
        if len(options) > 100:
            options = options[:100]

        # If no valid options remain, treat as text field
        if not options:
            options = None

    # Build column
    col = Column()
    col.title = title
    col.index = i + 1  # Each column gets unique index
    col.type = 'PICKLIST' if options else 'TEXT_NUMBER'
    col.primary = False

    if options:
        col.options = options

    columns_to_add.append(col)

print(f"\n🧩 Processed {len(columns_to_add)} columns for Smartsheet:")
for c in columns_to_add:
    print(f"Index: {c.index}, Title: '{c.title}' ({len(c.title)} chars), Primary: {c.primary}")
    if hasattr(c, 'options') and c.options:
        print(f"   Options ({len(c.options)}): {c.options[:3]}...")  # Show first 3 options

# Work with existing Smartsheet
try:
    # Get existing sheet info
    sheet = ss.Sheets.get_sheet(SHEET_ID)
    print(f"✅ Connected to existing sheet: '{sheet.name}' (ID: {SHEET_ID})")
    print(f"Current columns: {len(sheet.columns)}")

    # Show existing columns
    print("\n📋 Existing columns:")
    for col in sheet.columns:
        print(f"  - {col.title} (Index: {col.index}, Primary: {col.primary})")

    # Optional: Clear non-primary columns first (uncomment if you want to start fresh)
    print("\n🗑 Clearing existing non-primary columns...")
    for col in sheet.columns:
        if not col.primary:
            ss.Sheets.delete_column(SHEET_ID, col.id)
            print(f"   Deleted: {col.title}")
    time.sleep(3)  # Wait for deletions to complete

    # Get the current highest index to know where to start adding
    max_index = max([col.index for col in sheet.columns]) if sheet.columns else 0
    insertion_index = max_index + 1

    print(f"\n🔧 Preparing to add {len(columns_to_add)} new columns at index {insertion_index}")

    # Add columns ONE BY ONE (Smartsheet batch requirements are tricky)
    added_count = 0

    for i, col in enumerate(columns_to_add):
        # Set the same insertion index for each column
        col.index = insertion_index

        try:
            response = ss.Sheets.add_columns(SHEET_ID, [col])  # Add one column at a time
            added_count += 1

            if added_count % 10 == 0:  # Progress update every 10 columns
                print(f"✅ Added {added_count} columns so far...")

            time.sleep(0.5)  # Small delay between individual columns

        except Exception as col_error:
            print(f"❌ Error adding column '{col.title}': {str(col_error)}")

            # Try to identify the specific issue
            if len(col.title) > 50:
                print(f"   ⚠️  Title too long: '{col.title}' ({len(col.title)} chars)")
            if hasattr(col, 'options') and col.options and len(col.options) > 100:
                print(f"   ⚠️  Too many options: {len(col.options)}")

            # Continue with next column
            continue

    print(f"\n🎉 Finished! Added {added_count} out of {len(columns_to_add)} columns to your sheet.")
    print(f"Sheet URL: https://app.smartsheet.com/sheets/{SHEET_ID}")

    # Get updated sheet info
    updated_sheet = ss.Sheets.get_sheet(SHEET_ID)
    print(f"Final column count: {len(updated_sheet.columns)}")

except Exception as e:
    print(f"❌ Error working with sheet: {str(e)}")
    print("\nMake sure to:")
    print("1. Replace 'YOUR_API_TOKEN_HERE' with your actual Smartsheet API token")
    print("2. Replace 'YOUR_SHEET_ID_HERE' with your actual sheet ID")
    print("3. Ensure you have edit permissions for the sheet")
    print("4. Check that your Word document path is correct")

    # If error contains column info, show it
    if "column.title" in str(e):
        print("\n📏 Column title length issues detected. Check that all titles are ≤50 characters.")

print("\n" + "="*60)
print("SETUP CHECKLIST:")
print("✓ Run the parser first to create 'columns' and 'dropdowns' variables")
print("✓ Replace API_TOKEN with your actual Smartsheet API token")
print("✓ Replace SHEET_ID with your actual sheet ID")
print("✓ Install required packages: pip install smartsheet-python-sdk")
print("✓ Make sure you have edit permissions on the target sheet")
# Out:
# 🧩 Processed 101 columns for Smartsheet:
# Index: 1, Title: 'Type of Change' (14 chars), Primary: False
#    Options (4): ['New Supplier', 'Re-classification', 'Remove Supplier']...
# Index: 2, Title: 'New Supplier Sub-type' (21 chars), Primary: False
#    Options (3): ['Secondary/Alternate', 'Experimental/R&D Evaluation', 'NPI']...
# Index: 3, Title: 'Reason for Change' (17 chars), Primary: False
# Index: 4, Title: 'Supplier Company Name' (21 chars), Primary: False
# Index: 5, Title: 'Supplier Address' (16 chars), Primary: False
# Index: 6, Title: 'Supplier Phone Number' (21 chars), Primary: False
# Index: 7, Title: 'Supplier Website' (16 chars), Primary: False
# Index: 8, Title: 'Primary Contact 1 Name' (22 chars), Primary: False
# Index: 9, Title: 'Primary Contact 1 Title' (23 chars), Primary: False
# Index: 10, Title: 'Primary Contact 1 Email' (23 chars), Primary: False
# Index: 11, Title: 'Primary Contact 2 Name' (22 chars), Primary: False
# Index: 12, Title: 'Primary Contact 2 Title' (23 chars), Primary: False
# Index: 13, Title: 'Primary Contact 2 Email' (23 chars), Primary: False
# Index: 14, Title: 'Supplier Type' (13 chars), Primary: False
#    Options (3): ['Manufacturer of a Good', 'Vendor', 'Packaging Supplier']...
# Index: 15, Title: 'Vendor Sub-type' (15 chars), Primary: False
#    Options (2): ['Service Provider', 'Distributor']...
# Index: 16, Title: 'Contract Required for Service Provider' (38 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 17, Title: 'NDA Required' (12 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 18, Title: 'NDA Effective Date' (18 chars), Primary: False
# Index: 19, Title: 'NDA Term or Duration' (20 chars), Primary: False
# Index: 20, Title: 'Part or Service Description' (27 chars), Primary: False
# Index: 21, Title: 'Supplier Catalog Numbers' (24 chars), Primary: False
# Index: 22, Title: 'Part/Service Type' (17 chars), Primary: False
#    Options (3): ['Off-the-Shelf', 'Custom', 'One-time']...
# Index: 23, Title: 'Supplier Source Type' (20 chars), Primary: False
#    Options (3): ['Sole Source', 'One of 2 Sources', 'One of ≥3 Sources']...
# Index: 24, Title: 'Associated System/Instrument/Process' (36 chars), Primary: False
# Index: 25, Title: 'Estimated Annual Spend' (22 chars), Primary: False
# Index: 26, Title: 'Origin of Part or Service' (25 chars), Primary: False
#    Options (5): ['USA', 'Canada', 'Mexico']...
# Index: 27, Title: 'EMEA/APAC Country Specification' (31 chars), Primary: False
# Index: 28, Title: 'Used in Manufacture or Testing' (30 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 29, Title: 'Used for RUO/GMP/IVD Product' (28 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 30, Title: 'Product Exported to EU' (22 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 31, Title: 'Supplier Provides GMP/IVD Product' (33 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 32, Title: 'Supplier Provides IVD Device (ProteinSimple Leg...' (50 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 33, Title: 'Product for IVD Sold in EU Under IVDR' (37 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 34, Title: 'Impacts Design Outputs for RUO/GMP/IVD' (38 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 35, Title: 'Influences Test Result' (22 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 36, Title: 'Raw Material Requires In-house Testing' (38 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 37, Title: 'Requires Process Validation' (27 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 38, Title: 'Internal Lead Time' (18 chars), Primary: False
#    Options (6): ['≤ 1 week', '1-2 weeks', '2-4 weeks']...
# Index: 39, Title: 'Supplier Tax ID/SS#' (19 chars), Primary: False
# Index: 40, Title: 'Payment Terms' (13 chars), Primary: False
# Index: 41, Title: 'Payment Method' (14 chars), Primary: False
#    Options (4): ['Check', 'Wire', 'ACH']...
# Index: 42, Title: 'Is 1099 Vendor' (14 chars), Primary: False
#    Options (2): ['Yes', 'No']...
# Index: 43, Title: 'ACH Payee Name' (14 chars), Primary: False
# Index: 44, Title: 'Bank Routing Number' (19 chars), Primary: False
# Index: 45, Title: 'Bank Name' (9 chars), Primary: False
# Index: 46, Title: 'Bank Account Number' (19 chars), Primary: False
# Index: 47, Title: 'Bank Address' (12 chars), Primary: False
# Index: 48, Title: 'Financial Health - Likelihood' (29 chars), Primary: False
# Index: 49, Title: 'Financial Health - Impact' (25 chars), Primary: False
# Index: 50, Title: 'Country/Geopolitical - Likelihood' (33 chars), Primary: False
# Index: 51, Title: 'Country/Geopolitical - Impact' (29 chars), Primary: False
# Index: 52, Title: 'ESG Compliance - Likelihood' (27 chars), Primary: False
# Index: 53, Title: 'ESG Compliance - Impact' (23 chars), Primary: False
# Index: 54, Title: 'Regulatory Exposure - Likelihood' (32 chars), Primary: False
# Index: 55, Title: 'Regulatory Exposure - Impact' (28 chars), Primary: False
# Index: 56, Title: 'Operational Risk - Likelihood' (29 chars), Primary: False
# Index: 57, Title: 'Operational Risk - Impact' (25 chars), Primary: False
# Index: 58, Title: 'Cybersecurity Risk - Likelihood' (31 chars), Primary: False
# Index: 59, Title: 'Cybersecurity Risk - Impact' (27 chars), Primary: False
# Index: 60, Title: 'Supply Market Risk - Likelihood' (31 chars), Primary: False
# Index: 61, Title: 'Supply Market Risk - Impact' (27 chars), Primary: False
# Index: 62, Title: 'Benchmark Performance - Likelihood' (34 chars), Primary: False
# Index: 63, Title: 'Benchmark Performance - Impact' (30 chars), Primary: False
# Index: 64, Title: 'Risk Mitigation Actions' (23 chars), Primary: False
# Index: 65, Title: 'Risk Mitigation Task Owners' (27 chars), Primary: False
# Index: 66, Title: 'Risk Mitigation Completion Date' (31 chars), Primary: False
# Index: 67, Title: 'Supplier Classification' (23 chars), Primary: False
#    Options (4): ['Critical', 'Major', 'Minor']...
# Index: 68, Title: 'Supplier Code of Conduct - Submitted Date' (41 chars), Primary: False
# Index: 69, Title: 'Supplier Code of Conduct - Received Date' (40 chars), Primary: False
# Index: 70, Title: 'Supplier Change Notification - Submitted Date' (45 chars), Primary: False
# Index: 71, Title: 'Supplier Change Notification - Received Date' (44 chars), Primary: False
# Index: 72, Title: 'Supplier Evaluation Questionnaire - Submitted Date' (50 chars), Primary: False
# Index: 73, Title: 'Supplier Evaluation Questionnaire - Received Date' (49 chars), Primary: False
# Index: 74, Title: 'Supplier Quality Agreement - Submitted Date' (43 chars), Primary: False
# Index: 75, Title: 'Supplier Quality Agreement - Received Date' (42 chars), Primary: False
# Index: 76, Title: 'Quality System Certifications - Submitted Date' (46 chars), Primary: False
# Index: 77, Title: 'Quality System Certifications - Received Date' (45 chars), Primary: False
# Index: 78, Title: 'Resume/CV - Submitted Date' (26 chars), Primary: False
# Index: 79, Title: 'Resume/CV - Received Date' (25 chars), Primary: False
# Index: 80, Title: 'Supplier Quality Audit - Submitted Date' (39 chars), Primary: False
# Index: 81, Title: 'Supplier Quality Audit - Received Date' (38 chars), Primary: False
# Index: 82, Title: 'Audit Type' (10 chars), Primary: False
#    Options (3): ['N/A', 'Remote', 'On-Site']...
# Index: 83, Title: 'Audit Justification' (19 chars), Primary: False
# Index: 84, Title: 'Audit Scheduled Date' (20 chars), Primary: False
# Index: 85, Title: 'Final Type of Change' (20 chars), Primary: False
#    Options (4): ['New Supplier', 'Re-classification', 'Remove Supplier']...
# Index: 86, Title: 'Approval Status' (15 chars), Primary: False
#    Options (4): ['Approved', 'Conditional Approval', 'Not Approved']...
# Index: 87, Title: 'Conditional Approval Timeline' (29 chars), Primary: False
# Index: 88, Title: 'Conditional Approval Conditions' (31 chars), Primary: False
# Index: 89, Title: 'Supplier ID (MAS ERP)' (21 chars), Primary: False
# Index: 90, Title: 'MAS ERP Update Date' (19 chars), Primary: False
# Index: 91, Title: 'ASL Update Date' (15 chars), Primary: False
# Index: 92, Title: 'Arena e-QMS Update Date' (23 chars), Primary: False
# Index: 93, Title: 'Requestor Name' (14 chars), Primary: False
# Index: 94, Title: 'Requestor Department' (20 chars), Primary: False
# Index: 95, Title: 'Request Date' (12 chars), Primary: False
# Index: 96, Title: 'Procurement Name' (16 chars), Primary: False
# Index: 97, Title: 'Procurement Date' (16 chars), Primary: False
# Index: 98, Title: 'Supplier Quality Name' (21 chars), Primary: False
# Index: 99, Title: 'Supplier Quality Date' (21 chars), Primary: False
# Index: 100, Title: 'Final Approver Name' (19 chars), Primary: False
# Index: 101, Title: 'Final Approval Date' (19 chars), Primary: False
# ✅ Connected to existing sheet: 'SQM-python' (ID: 6327211310141316)
# Current columns: 102
#
# 📋 Existing columns:
#   - Primary Column (Index: 0, Primary: True)
#   - Type of Change (Index: 1, Primary: None)
#   - New Supplier Sub-type (Index: 2, Primary: None)
#   - Reason for Change (Index: 3, Primary: None)
#   - Supplier Company Name (Index: 4, Primary: None)
#   - Supplier Address (Index: 5, Primary: None)
#   - Supplier Phone Number (Index: 6, Primary: None)
#   - Supplier Website (Index: 7, Primary: None)
#   - Primary Contact 1 Name (Index: 8, Primary: None)
#   - Primary Contact 1 Title (Index: 9, Primary: None)
#   - Primary Contact 1 Email (Index: 10, Primary: None)
#   - Primary Contact 2 Name (Index: 11, Primary: None)
#   - Primary Contact 2 Title (Index: 12, Primary: None)
#   - Primary Contact 2 Email (Index: 13, Primary: None)
#   - Supplier Type (Index: 14, Primary: None)
#   - Vendor Sub-type (Index: 15, Primary: None)
#   - Contract Required for Service Provider (Index: 16, Primary: None)
#   - NDA Required (Index: 17, Primary: None)
#   - NDA Effective Date (Index: 18, Primary: None)
#   - NDA Term or Duration (Index: 19, Primary: None)
#   - Part or Service Description (Index: 20, Primary: None)
#   - Supplier Catalog Numbers (Index: 21, Primary: None)
#   - Part/Service Type (Index: 22, Primary: None)
#   - Supplier Source Type (Index: 23, Primary: None)
#   - Associated System/Instrument/Process (Index: 24, Primary: None)
#   - Estimated Annual Spend (Index: 25, Primary: None)
#   - Origin of Part or Service (Index: 26, Primary: None)
#   - EMEA/APAC Country Specification (Index: 27, Primary: None)
#   - Used in Manufacture or Testing (Index: 28, Primary: None)
#   - Used for RUO/GMP/IVD Product (Index: 29, Primary: None)
#   - Product Exported to EU (Index: 30, Primary: None)
#   - Supplier Provides GMP/IVD Product (Index: 31, Primary: None)
#   - Supplier Provides IVD Device (ProteinSimple Leg... (Index: 32, Primary: None)
#   - Product for IVD Sold in EU Under IVDR (Index: 33, Primary: None)
#   - Impacts Design Outputs for RUO/GMP/IVD (Index: 34, Primary: None)
#   - Influences Test Result (Index: 35, Primary: None)
#   - Raw Material Requires In-house Testing (Index: 36, Primary: None)
#   - Requires Process Validation (Index: 37, Primary: None)
#   - Internal Lead Time (Index: 38, Primary: None)
#   - Supplier Tax ID/SS# (Index: 39, Primary: None)
#   - Payment Terms (Index: 40, Primary: None)
#   - Payment Method (Index: 41, Primary: None)
#   - Is 1099 Vendor (Index: 42, Primary: None)
#   - ACH Payee Name (Index: 43, Primary: None)
#   - Bank Routing Number (Index: 44, Primary: None)
#   - Bank Name (Index: 45, Primary: None)
#   - Bank Account Number (Index: 46, Primary: None)
#   - Bank Address (Index: 47, Primary: None)
#   - Financial Health - Likelihood (Index: 48, Primary: None)
#   - Financial Health - Impact (Index: 49, Primary: None)
#   - Country/Geopolitical - Likelihood (Index: 50, Primary: None)
#   - Country/Geopolitical - Impact (Index: 51, Primary: None)
#   - ESG Compliance - Likelihood (Index: 52, Primary: None)
#   - ESG Compliance - Impact (Index: 53, Primary: None)
#   - Regulatory Exposure - Likelihood (Index: 54, Primary: None)
#   - Regulatory Exposure - Impact (Index: 55, Primary: None)
#   - Operational Risk - Likelihood (Index: 56, Primary: None)
#   - Operational Risk - Impact (Index: 57, Primary: None)
#   - Cybersecurity Risk - Likelihood (Index: 58, Primary: None)
#   - Cybersecurity Risk - Impact (Index: 59, Primary: None)
#   - Supply Market Risk - Likelihood (Index: 60, Primary: None)
#   - Supply Market Risk - Impact (Index: 61, Primary: None)
#   - Benchmark Performance - Likelihood (Index: 62, Primary: None)
#   - Benchmark Performance - Impact (Index: 63, Primary: None)
#   - Risk Mitigation Actions (Index: 64, Primary: None)
#   - Risk Mitigation Task Owners (Index: 65, Primary: None)
#   - Risk Mitigation Completion Date (Index: 66, Primary: None)
#   - Supplier Classification (Index: 67, Primary: None)
#   - Supplier Code of Conduct - Submitted Date (Index: 68, Primary: None)
#   - Supplier Code of Conduct - Received Date (Index: 69, Primary: None)
#   - Supplier Change Notification - Submitted Date (Index: 70, Primary: None)
#   - Supplier Change Notification - Received Date (Index: 71, Primary: None)
#   - Supplier Evaluation Questionnaire - Submitted Date (Index: 72, Primary: None)
#   - Supplier Evaluation Questionnaire - Received Date (Index: 73, Primary: None)
#   - Supplier Quality Agreement - Submitted Date (Index: 74, Primary: None)
#   - Supplier Quality Agreement - Received Date (Index: 75, Primary: None)
#   - Quality System Certifications - Submitted Date (Index: 76, Primary: None)
#   - Quality System Certifications - Received Date (Index: 77, Primary: None)
#   - Resume/CV - Submitted Date (Index: 78, Primary: None)
#   - Resume/CV - Received Date (Index: 79, Primary: None)
#   - Supplier Quality Audit - Submitted Date (Index: 80, Primary: None)
#   - Supplier Quality Audit - Received Date (Index: 81, Primary: None)
#   - Audit Type (Index: 82, Primary: None)
#   - Audit Justification (Index: 83, Primary: None)
#   - Audit Scheduled Date (Index: 84, Primary: None)
#   - Final Type of Change (Index: 85, Primary: None)
#   - Approval Status (Index: 86, Primary: None)
#   - Conditional Approval Timeline (Index: 87, Primary: None)
#   - Conditional Approval Conditions (Index: 88, Primary: None)
#   - Supplier ID (MAS ERP) (Index: 89, Primary: None)
#   - MAS ERP Update Date (Index: 90, Primary: None)
#   - ASL Update Date (Index: 91, Primary: None)
#   - Arena e-QMS Update Date (Index: 92, Primary: None)
#   - Requestor Name (Index: 93, Primary: None)
#   - Requestor Department (Index: 94, Primary: None)
#   - Request Date (Index: 95, Primary: None)
#   - Procurement Name (Index: 96, Primary: None)
#   - Procurement Date (Index: 97, Primary: None)
#   - Supplier Quality Name (Index: 98, Primary: None)
#   - Supplier Quality Date (Index: 99, Primary: None)
#   - Final Approver Name (Index: 100, Primary: None)
#   - Final Approval Date (Index: 101, Primary: None)
#
# 🗑 Clearing existing non-primary columns...
#    Deleted: Type of Change
#    Deleted: New Supplier Sub-type
#    Deleted: Reason for Change
#    Deleted: Supplier Company Name
#    Deleted: Supplier Address
#    Deleted: Supplier Phone Number
#    Deleted: Supplier Website
#    Deleted: Primary Contact 1 Name
#    Deleted: Primary Contact 1 Title
#    Deleted: Primary Contact 1 Email
#    Deleted: Primary Contact 2 Name
#    Deleted: Primary Contact 2 Title
#    Deleted: Primary Contact 2 Email
#    Deleted: Supplier Type
#    Deleted: Vendor Sub-type
#    Deleted: Contract Required for Service Provider
#    Deleted: NDA Required
#    Deleted: NDA Effective Date
#    Deleted: NDA Term or Duration
#    Deleted: Part or Service Description
#    Deleted: Supplier Catalog Numbers
#    Deleted: Part/Service Type
#    Deleted: Supplier Source Type
#    Deleted: Associated System/Instrument/Process
#    Deleted: Estimated Annual Spend
#    Deleted: Origin of Part or Service
#    Deleted: EMEA/APAC Country Specification
#    Deleted: Used in Manufacture or Testing
#    Deleted: Used for RUO/GMP/IVD Product
#    Deleted: Product Exported to EU
#    Deleted: Supplier Provides GMP/IVD Product
#    Deleted: Supplier Provides IVD Device (ProteinSimple Leg...
#    Deleted: Product for IVD Sold in EU Under IVDR
#    Deleted: Impacts Design Outputs for RUO/GMP/IVD
#    Deleted: Influences Test Result
#    Deleted: Raw Material Requires In-house Testing
#    Deleted: Requires Process Validation
#    Deleted: Internal Lead Time
#    Deleted: Supplier Tax ID/SS#
#    Deleted: Payment Terms
#    Deleted: Payment Method
#    Deleted: Is 1099 Vendor
#    Deleted: ACH Payee Name
#    Deleted: Bank Routing Number
#    Deleted: Bank Name
#    Deleted: Bank Account Number
#    Deleted: Bank Address
#    Deleted: Financial Health - Likelihood
#    Deleted: Financial Health - Impact
#    Deleted: Country/Geopolitical - Likelihood
#    Deleted: Country/Geopolitical - Impact
#    Deleted: ESG Compliance - Likelihood
#    Deleted: ESG Compliance - Impact
#    Deleted: Regulatory Exposure - Likelihood
#    Deleted: Regulatory Exposure - Impact
#    Deleted: Operational Risk - Likelihood
#    Deleted: Operational Risk - Impact
#    Deleted: Cybersecurity Risk - Likelihood
#    Deleted: Cybersecurity Risk - Impact
#    Deleted: Supply Market Risk - Likelihood
#    Deleted: Supply Market Risk - Impact
#    Deleted: Benchmark Performance - Likelihood
#    Deleted: Benchmark Performance - Impact
#    Deleted: Risk Mitigation Actions
#    Deleted: Risk Mitigation Task Owners
#    Deleted: Risk Mitigation Completion Date
#    Deleted: Supplier Classification
#    Deleted: Supplier Code of Conduct - Submitted Date
#    Deleted: Supplier Code of Conduct - Received Date
#    Deleted: Supplier Change Notification - Submitted Date
#    Deleted: Supplier Change Notification - Received Date
#    Deleted: Supplier Evaluation Questionnaire - Submitted Date
#    Deleted: Supplier Evaluation Questionnaire - Received Date
#    Deleted: Supplier Quality Agreement - Submitted Date
#    Deleted: Supplier Quality Agreement - Received Date
#    Deleted: Quality System Certifications - Submitted Date
#    Deleted: Quality System Certifications - Received Date
#    Deleted: Resume/CV - Submitted Date
#    Deleted: Resume/CV - Received Date
#    Deleted: Supplier Quality Audit - Submitted Date
#    Deleted: Supplier Quality Audit - Received Date
#    Deleted: Audit Type
#    Deleted: Audit Justification
#    Deleted: Audit Scheduled Date
#    Deleted: Final Type of Change
#    Deleted: Approval Status
#    Deleted: Conditional Approval Timeline
#    Deleted: Conditional Approval Conditions
#    Deleted: Supplier ID (MAS ERP)
#    Deleted: MAS ERP Update Date
#    Deleted: ASL Update Date
#    Deleted: Arena e-QMS Update Date
#    Deleted: Requestor Name
#    Deleted: Requestor Department
#    Deleted: Request Date
#    Deleted: Procurement Name
#    Deleted: Procurement Date
#    Deleted: Supplier Quality Name
#    Deleted: Supplier Quality Date
#    Deleted: Final Approver Name
#    Deleted: Final Approval Date
#
# 🔧 Preparing to add 101 new columns at index 102
# ✅ Added 10 columns so far...
# ✅ Added 20 columns so far...
# ✅ Added 30 columns so far...
# ✅ Added 40 columns so far...
# ✅ Added 50 columns so far...
# ✅ Added 60 columns so far...
# ✅ Added 70 columns so far...
# ✅ Added 80 columns so far...
# ✅ Added 90 columns so far...
# ✅ Added 100 columns so far...
#
# 🎉 Finished! Added 101 out of 101 columns to your sheet.
# Sheet URL: https://app.smartsheet.com/sheets/6327211310141316
# Final column count: 102
#
# ============================================================
# SETUP CHECKLIST:
# ✓ Run the parser first to create 'columns' and 'dropdowns' variables
# ✓ Replace API_TOKEN with your actual Smartsheet API token
# ✓ Replace SHEET_ID with your actual sheet ID
# ✓ Install required packages: pip install smartsheet-python-sdk
# ✓ Make sure you have edit permissions on the target sheet
